# %%
# %load_ext autoreload
# %autoreload 2
# Enables autoreload; learn more at https://docs.databricks.com/en/files/workspace-modules.html#autoreload-for-python-modules
# To disable autoreload; run %autoreload 0

# %%
from utils.Config import Config
from IngestionFunction import Ingestion
from datetime import datetime

# %%
notebook_started_at = datetime.now()

# %%
FILE_NAMES = dbutils.fs.ls(Config.RAW_PATH)

# %%
DATASET = {
        path.name.split("_")[1]: path.name for path in FILE_NAMES
    }
print(DATASET)

# %%
number_of_tables_added = 0
for table_name, path in DATASET.items():
    ingest = Ingestion(spark=spark, volume_csv= path, table_name=table_name)
    ingest.ingest()
    number_of_tables_added +=1
print(number_of_tables_added)

# %%
notebook_ended_at = datetime.now()
metadata = {
    "number of tables ingested": number_of_tables_added,
    "notebook started at": notebook_started_at.strftime("%Y-%m-%d %H:%M:%S"),
    "notebook ended at": notebook_ended_at.strftime("%Y-%m-%d %H:%M:%S"),
    "run duration": str(notebook_ended_at - notebook_started_at),
    "notebook name": "Ingestion"
}

# %%
print(metadata)
